# %%
# !uv pip install opencv-python
# Out:
# Resolved 2 packages in 1.97s
# Prepared 2 packages in 35.88s
# Installed 2 packages in 66ms
#  + numpy==2.2.5
#  + opencv-python==4.11.0.86

# %%
import cv2

# Load pre-trained face detector model (Haar Cascade)
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Open the webcam
cap = cv2.VideoCapture(0)  # 0 means default webcam

while True:
    # Read a frame from webcam
    ret, frame = cap.read()

    # Convert the frame to grayscale (face detection works better this way)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    # Draw rectangles around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Show the result in a window
    cv2.imshow('Face Detection', frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 17
#      14 gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      16 # Detect faces
# ---> 17 faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
#      19 # Draw rectangles around the faces
#      20 for (x, y, w, h) in faces:
#
# KeyboardInterrupt:
